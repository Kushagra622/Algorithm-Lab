# %% [markdown]
# <a href="https://colab.research.google.com/github/Kushagra622/Algorithm-Lab/blob/main/Lab_5_241b622.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 2. Divide and Conquer (Sorting)

# %% [markdown]
# - **Created by Dr. Ajay

# %% [markdown]
# Write a python program to perform **selection sort**.
# - ** -Algorithm
# * Step 1: Read the number of elements for the list from the user.
# * Step 2: Using for loop insert the elements in the list.
# * Step 3: Initialize the minimum element as min=numbers[i].
# * Step 4: Using the swap method the elements are sorted accordingly.
# * Step 5: Print the sorted list.

# %%
#write code for above cell and compute the running time and also plot graph.
import time
import random
import matplotlib.pyplot as plt
def selection_sort(numbers):
    n = len(numbers)
    for i in range(n):
        min_index = i
        for j in range(i+1, n):
            if numbers[j] < numbers[min_index]:
                min_index = j
        numbers[i], numbers[min_index] = numbers[min_index], numbers[i]

    return numbers
n = int(input("Enter number of elements: "))

numbers = []
print("Enter elements:")
for i in range(n):
    element = int(input())
    numbers.append(element)

print("\nOriginal List:", numbers)

start_time = time.time()
sorted_list = selection_sort(numbers)
end_time = time.time()

print("\nSorted List:", sorted_list)

running_time = end_time - start_time
print("\nRunning Time for Selection Sort:", running_time, "seconds")

sizes = [10, 50, 100, 200, 400, 600, 800, 1000]
times = []

for size in sizes:
    test_list = [random.randint(1, 10000) for _ in range(size)]

    start = time.time()
    selection_sort(test_list)
    end = time.time()

    times.append(end - start)

plt.plot(sizes, times, marker="o")
plt.title("Selection Sort Running Time Graph")
plt.xlabel("Input Size (n)")
plt.ylabel("Time Taken (seconds)")
plt.grid(True)
plt.show()
# Out:
# Enter number of elements: 5
# Enter elements:
# 56
# 86
# 35
# 78
# 45
#
# Original List: [56, 86, 35, 78, 45]
#
# Sorted List: [35, 45, 56, 78, 86]
#
# Running Time for Selection Sort: 7.748603820800781e-05 seconds

# %% [markdown]
# In computer science, **merge sort** (also commonly spelled mergesort) is an efficient, general-purpose, comparison-based sorting algorithm. Most implementations produce a stable sort, which means that the order of equal elements is the same in the input and output. Merge sort is a divide and conquer algorithm that was invented by John von Neumann in 1945.
# Write a Python program to sort the elements using **merge sort** and plot a graph to the time taken versus n
# - Algorithm(Merge Sort is a divide and conquer algorithm. It divides	input array in two halve.s, calls itself for the two halves and then merges two sorted halves.)
# 1.	Divide the unsorted array into n partitions, each	partition contains 1 element.
# 2.	Repeatedly merge partitioned units to produce	new sublists until there is only l sublist remaining. This will be the sorted	.
# 3.	Compare the first element of the sublist with the first element of the sublist to its right.
# 4.	Merge the two sublists by	paring each element of the sublist and placing the smaller element into the	new sublist.
# 5.	Repeat step 3 and 4 untill	all sublists are merged into a single sorted sublist.

# %%
#write code for above cell and compute the running time and also plot graph.
# Merge Sort Program + Running Time Calculation + Graph Plotting

import time
import random
import matplotlib.pyplot as plt

# -------- Merge Sort Function ----------
def merge_sort(arr):
    if len(arr) <= 1:
        return arr

    mid = len(arr) // 2

    # Divide
    left_half = merge_sort(arr[:mid])
    right_half = merge_sort(arr[mid:])

    # Conquer (Merge)
    return merge(left_half, right_half)


# -------- Merge Function ----------
def merge(left, right):
    sorted_list = []
    i = j = 0

    # Compare and merge elements
    while i < len(left) and j < len(right):
        if left[i] < right[j]:
            sorted_list.append(left[i])
            i += 1
        else:
            sorted_list.append(right[j])
            j += 1

    # Add remaining elements
    sorted_list.extend(left[i:])
    sorted_list.extend(right[j:])

    return sorted_list


# --------- Main Program (User Input) ----------
n = int(input("Enter number of elements: "))

numbers = []
print("Enter elements:")
for i in range(n):
    element = int(input())
    numbers.append(element)

print("\nOriginal List:", numbers)

start_time = time.time()
sorted_list = merge_sort(numbers)
end_time = time.time()

print("\nSorted List:", sorted_list)

running_time = end_time - start_time
print("\nRunning Time for Merge Sort:", running_time, "seconds")

sizes = [10, 50, 100, 200, 500, 1000, 2000, 5000, 8000, 10000]
times = []
for size in sizes:
    test_list = [random.randint(1, 100000) for _ in range(size)]
    start = time.time()
    merge_sort(test_list)
    end = time.time()
    times.append(end - start)
plt.plot(sizes, times, marker="o")
plt.title("Merge Sort Running Time Graph")
plt.xlabel("Input Size (n)")
plt.ylabel("Time Taken (seconds)")
plt.grid(True)
plt.show()
# Out:
# Enter number of elements: 4
# Enter elements:
# 46
# 97
# 65
# 908
#
# Original List: [46, 97, 65, 908]
#
# Sorted List: [46, 65, 97, 908]
#
# Running Time for Merge Sort: 0.0001552104949951172 seconds

# %% [markdown]
# 4**Quicksort** (sometimes called partition-exchange sort) is an efficient sorting algorithm. Developed by British computer scientist Tony Hoare in 1959 and published in 1961, it is still a commonly used algorithm for sorting.
#
# Quicksort is a divide-and-conquer algorithm. It works by selecting a 'pivot' element from the array and partitioning the other elements into two sub-arrays, according to whether they are less than or greater than the pivot. The sub-arrays are then sorted recursively. This can be done in-place, requiring small additional amounts of memory to perform the sorting.
# Write a Python program to sort the elements using quick sort and plot a graph to the time taken versus n.
# - Algorithm
# 1.	Select a pivot element from the array.
# 2.	Partition the array into two sub-arrays. The elements in the first sub-array are less than the pivot element, while the elements in the second sub-array are greater than the pivot element.
# 3.	Recursively sort the sub-arrays created in Step 2.
# 4.	Join the sub-arrays and the pivot element together to	the sorted array.

# %%
#write code for above cell and compute the running time and also plot graph.
import time
import random
import matplotlib.pyplot as plt

def quick_sort(arr):
    if len(arr) <= 1:
        return arr

    pivot = arr[len(arr) // 2]

    left = [x for x in arr if x < pivot]
    middle = [x for x in arr if x == pivot]
    right = [x for x in arr if x > pivot]

    return quick_sort(left) + middle + quick_sort(right)


n = int(input("Enter number of elements: "))

numbers = []
print("Enter elements:")
for i in range(n):
    element = int(input())
    numbers.append(element)

print("\nOriginal List:", numbers)

start_time = time.time()
sorted_list = quick_sort(numbers)
end_time = time.time()

print("\nSorted List:", sorted_list)

running_time = end_time - start_time
print("\nRunning Time for Quick Sort:", running_time, "seconds")


sizes = [10, 50, 100, 200, 500, 1000, 2000, 5000, 8000, 10000]
times = []

for size in sizes:
    test_list = [random.randint(1, 100000) for _ in range(size)]

    start = time.time()
    quick_sort(test_list)
    end = time.time()

    times.append(end - start)

plt.plot(sizes, times, marker="o")
plt.title("Quick Sort Running Time Graph")
plt.xlabel("Input Size (n)")
plt.ylabel("Time Taken (seconds)")
plt.grid(True)
plt.show()
# Out:
# Enter number of elements: 5
# Enter elements:
# 89
# 57
# 90
# 65
# 89
#
# Original List: [89, 57, 90, 65, 89]
#
# Sorted List: [57, 65, 89, 89, 90]
#
# Running Time for Quick Sort: 8.296966552734375e-05 seconds

# %% [markdown]
# ### Experiment: compare sorting algorithms

# %%
# Experiment variables
n_list = [1000, 2000, 5000, 10000, 20000, 50000, 100000, 200000]
n_max = n_list[len(n_list) -1]

# %%
# Creating a random value (uniform)
ms = datetime.now().microsecond / 1000
random.seed(ms)

numbers = []
for i in range(n_max):
    numbers.append(int(random.random() * 1000))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1933783365.py in <cell line: 0>()
#       1 # Creating a random value (uniform)
# ----> 2 ms = datetime.now().microsecond / 1000
#       3 random.seed(ms)
#       4
#       5 numbers = []
#
# NameError: name 'datetime' is not defined

# %%
a_time = []
b_time = []
c_time = []

for l in n_list:
    a = copy.deepcopy(numbers[0:l])
    b = copy.deepcopy(numbers[0:l])
    c = copy.deepcopy(numbers[0:l])

    start_time = timeit.default_timer()
    quick_sort(a)
    a_time.append((timeit.default_timer() - start_time) * 1000)

    start_time = timeit.default_timer()
    merge_sort(b)
    b_time.append((timeit.default_timer() - start_time) * 1000)

    start_time = timeit.default_timer()
    selection.sort()
    c_time.append((timeit.default_timer() - start_time) * 1000)

# %%
# Plotting results
plt.figure(figsize=(10, 5))
plt.plot(a_time, linewidth = 1, marker="o")
plt.plot(b_time, linewidth = 1, marker="o")
plt.plot(c_time, linewidth = 1, marker="o")
plt.xticks(np.arange(len(n_list)), n_list)
plt.title("Compare Sorting Algorithms", fontsize = 14)
plt.ylabel('Time (ms)')
plt.xlabel('n')
plt.legend(("Quicksort", "Mergesort", "Selection sort"), loc = "best")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-716276353.py in <cell line: 0>()
#       1 # Plotting results
# ----> 2 plt.figure(figsize=(10, 5))
#       3 plt.plot(a_time, linewidth = 1, marker="o")
#       4 plt.plot(b_time, linewidth = 1, marker="o")
#       5 plt.plot(c_time, linewidth = 1, marker="o")
#
# NameError: name 'plt' is not defined

# %%
#Corrected Version

import random, copy, timeit
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime

n_list = [1000, 2000, 5000, 10000, 20000, 50000, 100000, 200000]
n_max = n_list[-1]

ms = datetime.now().microsecond / 1000
random.seed(ms)

numbers = [int(random.random() * 1000) for _ in range(n_max)]

a_time = []
b_time = []
c_time = []

for l in n_list:
    a = copy.deepcopy(numbers[:l])
    b = copy.deepcopy(numbers[:l])
    c = copy.deepcopy(numbers[:l])

    start_time = timeit.default_timer()
    quick_sort(a)
    a_time.append((timeit.default_timer() - start_time) * 1000)

    start_time = timeit.default_timer()
    merge_sort(b)   # if merge_sort returns list, do: b = merge_sort(b)
    b_time.append((timeit.default_timer() - start_time) * 1000)

    if l <= 10000:  # selection sort limit
        start_time = timeit.default_timer()
        selection_sort(c)
        c_time.append((timeit.default_timer() - start_time) * 1000)
    else:
        c_time.append(None)

plt.figure(figsize=(10, 5))

plt.plot(n_list, a_time, linewidth=1, marker="o")
plt.plot(n_list, b_time, linewidth=1, marker="o")

# Plot selection sort only where it exists
sel_n = [n_list[i] for i in range(len(n_list)) if c_time[i] is not None]
sel_t = [t for t in c_time if t is not None]
plt.plot(sel_n, sel_t, linewidth=1, marker="o")

plt.title("Compare Sorting Algorithms", fontsize=14)
plt.ylabel("Time (ms)")
plt.xlabel("n")
plt.legend(("Quicksort", "Mergesort", "Selection sort"), loc="best")
plt.grid(True)
plt.show()
