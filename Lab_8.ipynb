# %% [markdown]
# <a href="https://colab.research.google.com/github/Kushagra622/Algorithm-Lab/blob/main/Lab_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Minimum Cost Spanning Tree
# Problem Description:
# A spanning tree of a graph can be defined as a graph with minimal set of edges that connect all vertices. A minimum spanning tree of a graph is a spanning tree of the graph with least weight (where the weight is computed by adding the weights of all the edges in the spanning tree). In general, a graph can have multiple minimum spanning trees. The problem is to find a minimum spanning tree of a graph.

# %% [markdown]
# This implementation uses a dictionary to represent the weighted graph, where the vertices are keys, and the values are dictionaries containing their adjacent vertices and their weights.
#
# Please note that this implementation assumes that the input graph is connected and weighted.
#
# First, let's create a simple graph to demonstrate Prim's algorithm:

# %%
graph = {
    "A": {"B": 10, "C": 15, "D": 20},
    "B": {"A": 10, "C": 12},
    "C": {"A": 15, "B": 12, "D": 18},
    "D": {"A": 20, "C": 18},
}

# %% [markdown]
# Now, let's implement Prim's algorithm:

# %%
def prim_algorithm(graph):
    min_tree = {}
    visited = set()
    min_tree[list(graph.keys())[0]] = []
    min_weight = 0

    while len(visited) < len(graph):
        min_edge = float('inf')
        next_vertex = None
        for vertex in min_tree:
            for adj_vertex, weight in graph[vertex].items():
                if adj_vertex not in visited:
                    if weight < min_edge:
                        min_edge = weight
                        next_vertex = adj_vertex

        min_tree[next_vertex] = []
        visited.add(next_vertex)
        min_weight += min_edge

    return min_tree, min_weight

# %% [markdown]
# Now, let's run the Prim's algorithm on the example graph:
# Keep in mind that this example uses a simple representation of a graph, but for more complex cases, you might want to use a library such as NetworkX to represent and manipulate graphs.

# %%
mst, min_weight = prim_algorithm(graph)
print("Minimum Spanning Tree: ", mst)
print("Minimum Weight: ", min_weight)
# Out:
# Minimum Spanning Tree:  {'A': [], 'B': [], 'C': [], 'D': []}
# Minimum Weight:  50

# %%
def prim_algorithm(graph):
    min_tree = {}
    visited = set()

    start_vertex = list(graph.keys())[0]
    visited.add(start_vertex)
    min_tree[start_vertex] = []

    min_weight = 0

    while len(visited) < len(graph):
        min_edge = float('inf')
        from_vertex = None
        to_vertex = None

        for vertex in visited:
            for adj_vertex, weight in graph[vertex].items():
                if adj_vertex not in visited and weight < min_edge:
                    min_edge = weight
                    from_vertex = vertex
                    to_vertex = adj_vertex

        if from_vertex not in min_tree:
            min_tree[from_vertex] = []

        min_tree[from_vertex].append((to_vertex, min_edge))

        visited.add(to_vertex)
        min_weight += min_edge

    return min_tree, min_weight

# %% [markdown]
# Take Differnt example of input graph as discussed in lecture slide and use above code to verify the output

# %%
# your sample input of graph

graph2 = {
    "A": {"B": 4, "H": 8},
    "B": {"A": 4, "C": 8, "H": 11},
    "C": {"B": 8, "D": 7, "F": 4, "I": 2},
    "D": {"C": 7, "E": 9, "F": 14},
    "E": {"D": 9, "F": 10},
    "F": {"C": 4, "D": 14, "E": 10, "G": 2},
    "G": {"F": 2, "H": 1, "I": 6},
    "H": {"A": 8, "B": 11, "G": 1, "I": 7},
    "I": {"C": 2, "G": 6, "H": 7}
}

# %%
#run prims algorithm for sample input
mst, min_weight = prim_algorithm(graph2)

print("Minimum Spanning Tree:", mst)
print("Minimum Weight:", min_weight)
# Out:
# Minimum Spanning Tree: {'A': [('B', 4), ('H', 8)], 'H': [('G', 1)], 'G': [('F', 2)], 'F': [('C', 4)], 'C': [('I', 2), ('D', 7)], 'D': [('E', 9)]}
# Minimum Weight: 37

# %% [markdown]
# Use same apporach for Kruskal's algorithm

# %%
# implement Kruskal's algorithm

def kruskal_algorithm(graph):

    parent = {}
    rank = {}

    def find(v):
        if parent[v] != v:
            parent[v] = find(parent[v])
        return parent[v]

    def union(v1, v2):
        root1 = find(v1)
        root2 = find(v2)

        if root1 != root2:
            if rank[root1] > rank[root2]:
                parent[root2] = root1
            else:
                parent[root1] = root2
                if rank[root1] == rank[root2]:
                    rank[root2] += 1

    edges = []

    for vertex in graph:
        parent[vertex] = vertex
        rank[vertex] = 0
        for adj, weight in graph[vertex].items():
            edges.append((weight, vertex, adj))

    edges = sorted(edges)

    mst = []
    min_weight = 0

    for weight, v1, v2 in edges:
        if find(v1) != find(v2):
            union(v1, v2)
            mst.append((v1, v2, weight))
            min_weight += weight

    return mst, min_weight

# %%
mst, weight = kruskal_algorithm(graph2)

print("Minimum Spanning Tree (Kruskal):", mst)
print("Minimum Weight:", weight)
# Out:
# Minimum Spanning Tree (Kruskal): [('G', 'H', 1), ('C', 'I', 2), ('F', 'G', 2), ('A', 'B', 4), ('C', 'F', 4), ('C', 'D', 7), ('A', 'H', 8), ('D', 'E', 9)]
# Minimum Weight: 37
